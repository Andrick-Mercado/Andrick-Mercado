# %%
import numpy as np

# %% [markdown]
# We have been subjected to a rather dull and uninspiring lecture about code we cannot yet understand.

# %%
# This is a function which computes the square root of 'A' 
# given the initial starting guess 'x0' up to the tolerance
# specified by 'tol'.

def babylon(x0,tol,A):
    x1 = (x0 + A/x0)/2.
    print(f"{x1:8f}")
    count = 1
    while np.abs(x1-x0)>tol:
        x0 = x1
        x1 = (x0 + A/x0)/2.
        print(f"{x1:16}")
        count += 1
    print( "The Babylonian Algorithm has approximated your root to be %1.16f after %d iterations" % (x1, count))

# %%
babylon(21, 1E-3, 31)
# 1.414
# Out:
# 11.238095238095237
# 6.998284907183212
# 5.713970830197196
# 5.5696348948764065
# 5.567764676934106
# 5.567764362830031
# The Babylonian Algorithm has approximated your root to be 5.5677643628300313 after 6 iterations
