# %% [markdown]
# # A Brief Introduction to Julia

# %% [markdown]
# * Julia > Python but people are too set in their ways to switch.
#
# * Please enjoy these videos in your free time and answer the questions as asked. I have included some optional videos in case you are interested in data science or machine learning.
#
# * For a Julia playground, you might want to try https://replit.com/
#
# * **(Optional)** Google Summer of Code is a global program focused on bringing more student developers into open source software development. Students work with an open source organization on a 10 week programming project during their break from school. https://summerofcode.withgoogle.com/

# %% [markdown]
# ## Run this code block

# %%
from IPython.display import YouTubeVideo

# %% [markdown]
# # Julia v Python

# %%
YouTubeVideo("GXYRgQ0zvq8")

# %% [markdown]
# **Julia vs Python**
# 1. It is the more time efficient choice for companies or developers when working with numbers in data science related work.
# 2. Currently Julia is faster than python, unless python is used with external libraries that have optimized code it doesn't compete against julia, as julia is a part of the petaflop club with essentially means that it past a calculation in under a certain amount of time which most programs don't stand a chance at passing.
# 3. Do to how young the programing language Julia is, it lack behind on the amount of libraries it has when compared to python as well as the optimization of such libraries.
# 4. It is safe to say that julia might be the fastest but since its the newest most new programmers go into set languages like python hence why the amount of support for such languages is so vast.
# 5. Well yet again we rich to the same conclussion of as a result of the age of the programming language its coommunity is obviously going to be smaller compare to something that has been out for way longer.

# %% [markdown]
# ## Introduction to Julia

# %%
YouTubeVideo("8h8rQyEpiZA")

# %% [markdown]
# ### Questions
#
# * How can you use Julia to print the line `"Hello earthlings"`?
#  * println("Hello earthlings")
# * How can we check the $\texttt{type}$ of a variable?
#  * typeof(variable here)
# * How can we create a dictionary type in Julia? If we wanted to populate a dictionary called $\texttt{phonebook}$, what are the commands?
#
#   phonebook = Dict("Jenny"=> "555-324", "GhostBusters"=> "555-345")
#   phonebook["kramer"] = "555-FILK" #adds new directory
#
#   println(phonebook["kramer"])
#
#   pop!(phonebook, "kramer") #removes kramer from dict

# %% [markdown]
# ## Introduction to Julia for Pythonistas

# %%
YouTubeVideo('Cj6bjqS5otM')

# %% [markdown]
# ### Questions
# * What is the two language problem?
#  * Essentially the problem revolves around the idea that languages such as python are one of two languages, the two being a performant and productive language, where python is more on the productive side while julia is on the performant side
#
# * When we say `Julia` *looks like* `Python` we are saying that they look similar syntactically. Give an example of a function in Python Code and an example of a function in Julia code.
#  * Python
# ````
# def sum(a):
#     s = 0.0
#     for x in a:
#         s+=x
#     return s
# ````
#  * Julia
# ````
# function sum(a)
#     s = 0.0
#     for x in a
#         s+=x
#     end
#     return s
# end
# ````
#
# * Please give an example of 5 Julia users, partners, and employers hiring Julia programmers
#  * 1 Intel
#  * 2 Disney
#  * 3 Amazon
#  * 4 Capital One
#  * 5 Google

# %% [markdown]
# # Intro to Julia for Python Devs
#
# * https://datatofish.com/add-julia-to-jupyter/
# * https://colab.research.google.com/drive/151EWCxdzcs1icHGOwLnxxAUiB5kTx5R7

# %%
YouTubeVideo("qhrY0c_BHs8")

# %% [markdown]
# ### Questions
#
# Please summarize this video... (TL;DR Check the end of the video)
#
# Summary
#
# ---
# Julia is
# * Essentially it is one of the best computer languages for data science specially when it comes to computing with large list of numbers or just performing big number computations with precision.
# * A programming language that surpases python even while using cython, hence why it is much better in the data science field.
#
#
# * The benefits of julia include c like speeds when compiling programs and can also get C and Fortran libraries .
# * As well as having low barriers to entry meaning easy installation and it is easy to learn as well.
# * There is multiple ways to download and its completly free, even jupiter notebooks works.

# %% [markdown]
# ## Introduction to Pluto

# %%
YouTubeVideo("IAF8DjrQSSk")

# %% [markdown]
# ### Questions
#
# * What is Pluto?
#  * Its an interactive notebook like jupiter, but unlike jupiter you dont have to call a cell where a value was previsouly stored in a specific variable again, as when you run it in an outside cell it would automatically run the cells where the variable originated from.
#
# * What are the **strong** points of Jupyter notebooks? What are the **pain** points?
#  * Strong Points: interactive and code, output & formatted text in one documented.
#  * Pain Points: Global scope is persistent, file format hinders version control, and notebook from one machine rarely works on another machine.
#
# * What is the reactive paradigm outlined in the presentation?
#  * In pluto notebooks you can put data all over the place with the same name variables and changed it, but whats special about pluto is that it runs the cells to not create any erros and in a way that the computer can fully execute the cell code.

# %% [markdown]
# ## Download Julia

# %% [markdown]
# **Download:** https://julialang.org/downloads/
#
# * Make sure to save it to your desktop so you can find it later.
# * Run Julia.
#  * Read some tutorials... https://www.geeksforgeeks.org/julia-language-introduction/
# * **Only on the first time we run Julia**
#  * We want to add the `Pkg` Pluto. For more info. https://juliapackages.com/p/pluto
#
#
# ###### TL;DR
#
# ````
# import Pkg; Pkg.add("Pluto");
# ````
#
# * **This step might take awhile**... *Please wait.*
#
# ````
# import Pluto; Pluto.run();
# ````

# %% [markdown]
# ## Pluto Tutorial

# %%
YouTubeVideo("6ewFgLR1LLY")

# %% [markdown]
# ### Questions
#
# * Julia environments
#  * Dr. Juan Klopper spends the first 11*ish* minutes droning on about Julia environments. Why are these useful? If you had to give me the TL;DR version of this, what would be your shortened explanaition for how to create Julia environments?
#  * Answer Goes Here
#
# * We just started a new notebook. Let's create a markdown cell so we can give our notebook a title... How can we execute **markdown** in a Pluto notebook cell?
#  * md"##title here"
# * A *multiline* code starts with **?** and ends with **?**...
#  * begin and end

# %% [markdown]
# # Markdown Guide

# %% [markdown]
# * [Markdown](https://docs.julialang.org/en/v1/stdlib/Markdown/)

# %% [markdown]
# ## Automatic Differentiation (Optional)

# %%
YouTubeVideo("vAp6nUMrKYg")

# %% [markdown]
# # Scientific Machine Learning (SciML) (Optional)

# %%
YouTubeVideo("QwVO0Xh2Hbg")
